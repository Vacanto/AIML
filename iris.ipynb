# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("file:///C:/Users/ANTO%20CHARLES/Downloads/iris/iris.data")

# %%
data
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data.head
# Out:
# <bound method NDFrame.head of      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]>

# %%
data.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.shape
# Out:
# (149, 5)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]>

# %%
sns.pairplot(data,vars=("5.1" , "3.5", "1.4" , 
                        "0.2" ),hue="Iris-setosa")

# %%
x=data.drop("Iris-setosa",axis=1)
Y=data["Iris-setosa"]

# %%
x.head
# Out:
# <bound method NDFrame.head of      5.1  3.5  1.4  0.2
# 0    4.9  3.0  1.4  0.2
# 1    4.7  3.2  1.3  0.2
# 2    4.6  3.1  1.5  0.2
# 3    5.0  3.6  1.4  0.2
# 4    5.4  3.9  1.7  0.4
# ..   ...  ...  ...  ...
# 144  6.7  3.0  5.2  2.3
# 145  6.3  2.5  5.0  1.9
# 146  6.5  3.0  5.2  2.0
# 147  6.2  3.4  5.4  2.3
# 148  5.9  3.0  5.1  1.8
#
# [149 rows x 4 columns]>

# %%
y.head
# Out:
# <bound method NDFrame.head of               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, Y_train, Y_test = train_test_split(x, Y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#      5.1  3.5  1.4  0.2
# 22   5.1  3.3  1.7  0.5
# 15   5.4  3.9  1.3  0.4
# 65   5.6  3.0  4.5  1.5
# 11   4.8  3.0  1.4  0.1
# 42   5.0  3.5  1.6  0.6
# ..   ...  ...  ...  ...
# 71   6.3  2.5  4.9  1.5
# 106  7.3  2.9  6.3  1.8
# 14   5.7  4.4  1.5  0.4
# 92   5.0  2.3  3.3  1.0
# 102  6.3  2.9  5.6  1.8
#
# [119 rows x 4 columns]

# %%
 Y_train
# Out:
# 22         Iris-setosa
# 15         Iris-setosa
# 65     Iris-versicolor
# 11         Iris-setosa
# 42         Iris-setosa
#             ...
# 71     Iris-versicolor
# 106     Iris-virginica
# 14         Iris-setosa
# 92     Iris-versicolor
# 102     Iris-virginica
# Name: Iris-setosa, Length: 119, dtype: object

# %%
x_test
# Out:
#      5.1  3.5  1.4  0.2
# 73   6.4  2.9  4.3  1.3
# 18   5.1  3.8  1.5  0.3
# 117  7.7  2.6  6.9  2.3
# 78   5.7  2.6  3.5  1.0
# 76   6.7  3.0  5.0  1.7
# 31   5.2  4.1  1.5  0.1
# 64   6.7  3.1  4.4  1.4
# 140  6.9  3.1  5.1  2.3
# 68   5.6  2.5  3.9  1.1
# 82   6.0  2.7  5.1  1.6
# 109  6.5  3.2  5.1  2.0
# 12   4.3  3.0  1.1  0.1
# 36   4.9  3.1  1.5  0.1
# 9    5.4  3.7  1.5  0.2
# 19   5.4  3.4  1.7  0.2
# 56   4.9  2.4  3.3  1.0
# 136  6.4  3.1  5.5  1.8
# 69   5.9  3.2  4.8  1.8
# 55   6.3  3.3  4.7  1.6
# 131  6.4  2.8  5.6  2.2
# 29   4.8  3.1  1.6  0.2
# 123  6.7  3.3  5.7  2.1
# 26   5.2  3.5  1.5  0.2
# 127  6.4  2.8  5.6  2.1
# 128  7.2  3.0  5.8  1.6
# 144  6.7  3.0  5.2  2.3
# 110  6.4  2.7  5.3  1.9
# 101  7.1  3.0  5.9  2.1
# 45   5.1  3.8  1.6  0.2
# 30   5.4  3.4  1.5  0.4

# %%
Y_test
# Out:
# 73     Iris-versicolor
# 18         Iris-setosa
# 117     Iris-virginica
# 78     Iris-versicolor
# 76     Iris-versicolor
# 31         Iris-setosa
# 64     Iris-versicolor
# 140     Iris-virginica
# 68     Iris-versicolor
# 82     Iris-versicolor
# 109     Iris-virginica
# 12         Iris-setosa
# 36         Iris-setosa
# 9          Iris-setosa
# 19         Iris-setosa
# 56     Iris-versicolor
# 136     Iris-virginica
# 69     Iris-versicolor
# 55     Iris-versicolor
# 131     Iris-virginica
# 29         Iris-setosa
# 123     Iris-virginica
# 26         Iris-setosa
# 127     Iris-virginica
# 128     Iris-virginica
# 144     Iris-virginica
# 110     Iris-virginica
# 101     Iris-virginica
# 45         Iris-setosa
# 30         Iris-setosa
# Name: Iris-setosa, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import classification_report,accuracy_score

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=knn.predict(x_test)

# %%
print("accuracy:",accuracy_score(Y_test,y_pred))
# Out:
# accuracy: 0.9333333333333333

# %%
print(classification_report(Y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      0.78      0.88         9
#  Iris-virginica       0.85      1.00      0.92        11
#
#        accuracy                           0.93        30
#       macro avg       0.95      0.93      0.93        30
#    weighted avg       0.94      0.93      0.93        30

# %%
x_test.head(2)
# Out:
#     5.1  3.5  1.4  0.2
# 73  6.4  2.9  4.3  1.3
# 18  5.1  3.8  1.5  0.3

# %%
ne=pd.DataFrame({"5.1":[5.4],"3.5":[3.9],"1.4":[1.3],"0.2":[0.3]})

# %%
prediction=knn.predict(ne)

# %%
prediction[0]
# Out:
# 'Iris-setosa'

# %%
ne=pd.DataFrame({"5.1":[5.4],"3.5":[13.9],"1.4":[11.3],"0.2":[10.3]})
prediction=knn.predict(ne)

# %%
prediction[0]
# Out:
# 'Iris-setosa'
